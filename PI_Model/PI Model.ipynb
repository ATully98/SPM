# %%
import run_model
import pandas as pd

# %%
Study_iter = 5 # number of study iterations to complete
ID = "Run1" # ID for outputfile
folder = "ExampleFolder" # Folder to which results are output
rootfolder = "C:/Users/atully/Jupyter/Notebooks/PI Models/" # path to folder holding code files
# to sample blocking behavior set a and/or b to "SAMPLE" - (a = "SAMPLE")
a = 1.05
b = 1.5
lam = 0.3
Blab = 8
Banc = 8
# Experiment key can be set to: "Coe", "IZZI", "Aitken", "Thellier"
Experiment_Key = "IZZI"

# %%
# run model
run_model.run(Study_iter,ID, folder, rootfolder, a, b, lam, Blab, Banc, Experiment_Key)
# Out:
# ExampleFolder/Run1_Out.csv has been deleted
# Programme Initiated: Wed, 31 Jul 2024 06:32:37
# C:/Users/atully/Jupyter/Notebooks/PI Models//Core_Files/Experiment_IZZI.txt
# Study Iteration: 0
# time: 31.875832319259644
# Study 0 complete
# Study Iteration: 1
# time: 33.4643976688385
# Study 1 complete
# Study Iteration: 2
# time: 31.33075737953186
# Study 2 complete
# Study Iteration: 3
# time: 34.57471299171448
# Study 3 complete
# Study Iteration: 4
# time: 34.044910192489624
# Study 4 complete
# --- 171.36371660232544 seconds ---
#
#
# ---Average time per sample: 33.058122110366824 seconds ---
#
#
# --- Run Time:  00:00:02:51  ---
# END
# Programme Finished: Wed, 31 Jul 2024 06:35:28

# %%
file = f"{rootfolder}{folder}/{ID}_Out.csv"
df = pd.read_csv(file)

# %%
display(df.describe())
# Out:
#         nmax   Blab  Anis_c           n        Tmin        Tmax        xbar  \
# count  455.0  455.0     0.0  455.000000  455.000000  455.000000  455.000000
# mean    14.0    8.0     NaN    6.000000   47.271694   87.087912    3.169082
# std      0.0    0.0     NaN    3.165758   33.510441   19.735476    1.109301
# min     14.0    8.0     NaN    2.000000    0.000000   12.931034    0.139778
# 25%     14.0    8.0     NaN    3.000000   12.931034   86.206897    2.496797
# 50%     14.0    8.0     NaN    5.000000   38.793103   97.413793    3.371775
# 75%     14.0    8.0     NaN    8.000000   77.586207   99.137931    4.155494
# max     14.0    8.0     NaN   14.000000   99.137931  100.000000    4.512429
#
#              ybar           b        Banc  ...  NLT_a_est  NLT_b_est  \
# count  455.000000  455.000000  455.000000  ...        0.0        0.0
# mean     0.955301   -0.764932    7.248571  ...        NaN        NaN
# std      0.961357    1.626442   12.417342  ...        NaN        NaN
# ...

# %%
display(df.head())
# Out:
#                                            Meas_Data  \
# 0  [[-3.20980009e+00 -7.93161849e-01 -3.05534215e...
# 1  [[-3.20980009e+00 -7.93161849e-01 -3.05534215e...
# 2  [[-3.20980009e+00 -7.93161849e-01 -3.05534215e...
# 3  [[-3.20980009e+00 -7.93161849e-01 -3.05534215e...
# 4  [[-3.20980009e+00 -7.93161849e-01 -3.05534215e...
#
#                                       Meas_Treatment  \
# 0  [1. 0. 1. 3. 1. 0. 2. 0. 1. 3. 1. 0. 2. 0. 1. ...
# 1  [1. 0. 1. 3. 1. 0. 2. 0. 1. 3. 1. 0. 2. 0. 1. ...
# 2  [1. 0. 1. 3. 1. 0. 2. 0. 1. 3. 1. 0. 2. 0. 1. ...
# 3  [1. 0. 1. 3. 1. 0. 2. 0. 1. 3. 1. 0. 2. 0. 1. ...
# 4  [1. 0. 1. 3. 1. 0. 2. 0. 1. 3. 1. 0. 2. 0. 1. ...
#
#                                            Meas_Temp Blab_orient  \
# 0  [[100.        ]\n [ 12.93103448]\n [ 12.931034...   [[0 0 1]]
# 1  [[100.        ]\n [ 12.93103448]\n [ 12.931034...   [[0 0 1]]
# 2  [[100.        ]\n [ 12.93103448]\n [ 12.931034...   [[0 0 1]]
# ...
